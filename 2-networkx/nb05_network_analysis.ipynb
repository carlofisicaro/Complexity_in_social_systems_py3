# %% [markdown]
# <center>
# <hr>
# <h1>Complessità nei sistemi sociali</h1>
# <h2>Laurea Magistrale in Fisica Dei Sistemi Complessi</h2>
# <h2>A.A. 2016/17</h2>
# <h3>Dr. Daniela Paolotti, Dr. Michele Tizzoni</h3>
# <h3>Basic network analysis with NetworkX, assortativity, resilience to attacks</h3>
# <hr>
# </center>

# %%
import networkx as nx
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Measure the connectivity and clustering of a graph

# %%
G=nx.Graph()

# %%
#Download the network file 'ca-AstroPh' from SNAP@Stanford
fh=open('./ca-AstroPh.txt','r')
for line in fh.readlines():
    s=line.strip().split()
    if s[0]!='#':
        origin=int(s[0])
        dest=int(s[1])
        G.add_edge(origin,dest)
fh.close()

# %%
print ("The graph has", len(G), "nodes")
print ("and",len(G.edges()),"edges")
# Out:
# The graph has 18772 nodes
# and 198110 edges

# %%
print ("Is the graph simply connected?", nx.is_connected(G))
# Out:
# Is the graph simply connected? False

# %% [markdown]
# ### Show the components of the graph

# %%
print ("The graph has", nx.number_connected_components(G),"connected components")
# Out:
# The graph has 290 connected components

# %%
for k in nx.connected_components(G):
    print (len(k))
# Out:
# 17903
# 2
# 3
# 4
# 8
# 2
# 2
# 4
# 3
# 5
# 3
# 3
# 2
# 2
# 5
# 5
# 2
# 7
# 2
# 3
# 10
# 3
# 4
# 4
# 4
# 2
# 2
# 3
# 6
# 4
# 2
# 4
# 2
# 3
# 2
# 2
# 5
# 4
# 6
# 2
# 2
# 5
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 2
# 4
# 2
# 3
# 3
# 2
# 3
# 3
# 2
# 3
# 3
# 5
# 3
# 2
# 3
# 5
# 3
# 2
# 3
# 2
# 2
# 3
# 2
# 3
# 4
# 3
# 3
# 3
# 3
# 2
# 5
# 2
# 4
# 2
# 4
# 10
# 2
# 3
# 3
# 3
# 4
# 3
# 2
# 3
# 2
# 2
# 3
# 5
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 9
# 2
# 3
# 4
# 3
# 4
# 3
# 3
# 5
# 5
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 4
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 3
# 2
# 2
# 4
# 2
# 2
# 4
# 4
# 3
# 3
# 2
# 2
# 3
# 3
# 3
# 2
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 2
# 12
# 2
# 3
# 8
# 3
# 2
# 2
# 7
# 4
# 3
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 4
# 2
# 3
# 2
# 3
# 2
# 4
# 2
# 4
# 2
# 4
# 4
# 2
# 5
# 2
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 3
# 3
# 3
# 3
# 8
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 4
# 1
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 5
# 2
# 4
# 2
# 6
# 18
# 3
# 2
# 3
# 3
# 2
# 2
# 3
# 4
# 2
# 2
# 4
# 3
# 3
# 4
# 7
# 5
# 2
# 3
# 3
# 2
# 2
# 4
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 2

# %% [markdown]
# ### Extract the largest Connected Component as a subgraph

# %%
nx.connected_component_subgraphs(G)
# Out:
# <generator object connected_component_subgraphs at 0x7f1dbf6ff308>

# %%
graphs = list(nx.connected_component_subgraphs(G))

# %%
graphs
# Out:
# [<networkx.classes.graph.Graph at 0x7f1dcc4036a0>,
#  <networkx.classes.graph.Graph at 0x7f1df10978d0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703940>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7039e8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703b00>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703c50>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703d68>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703eb8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703fd0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703f28>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703e80>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703dd8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703d30>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703c88>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703be0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703b38>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703748>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7036a0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703a20>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703978>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7038d0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703828>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7035f8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703550>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7034a8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf7033c8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703358>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703320>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703160>,
#  <networkx.classes.graph.Graph at 0x7f1dbf703080>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6dc6d8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6dc4e0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6dc0b8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6dc550>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1978>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1d30>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1f60>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1b00>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1da0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1f28>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1a58>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1cc0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f19e8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1c50>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1f98>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1be0>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1e48>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1eb8>,
#  <networkx.classes.graph.Graph at 0x7f1dbf6f1cf8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f048>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f0b8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f128>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f198>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f208>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f278>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f2e8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f358>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f3c8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f438>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f4a8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f518>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f588>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f5f8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f668>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f6d8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f748>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f7b8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f828>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f898>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f908>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f978>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5f9e8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fa58>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fac8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fb38>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fba8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fc18>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fc88>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fcf8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fd68>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fdd8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5fe48>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5feb8>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5ff28>,
#  <networkx.classes.graph.Graph at 0x7f1db6e5ff98>,
#  <networkx.classes.graph.Graph at 0x7f1db721e048>,
#  <networkx.classes.graph.Graph at 0x7f1db721e0b8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e128>,
#  <networkx.classes.graph.Graph at 0x7f1db721e198>,
#  <networkx.classes.graph.Graph at 0x7f1db721e208>,
#  <networkx.classes.graph.Graph at 0x7f1db721e278>,
#  <networkx.classes.graph.Graph at 0x7f1db721e2e8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e358>,
#  <networkx.classes.graph.Graph at 0x7f1db721e3c8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e438>,
#  <networkx.classes.graph.Graph at 0x7f1db721e4a8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e518>,
#  <networkx.classes.graph.Graph at 0x7f1db721e588>,
#  <networkx.classes.graph.Graph at 0x7f1db721e5f8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e668>,
#  <networkx.classes.graph.Graph at 0x7f1db721e6d8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e748>,
#  <networkx.classes.graph.Graph at 0x7f1db721e7b8>,
#  <networkx.classes.graph.Graph at 0x7f1db721e828>,
#  <networkx.classes.graph.Graph at 0x7f1db721e898>,
#  <networkx.classes.graph.Graph at 0x7f1db721e908>,
#  <networkx.classes.graph.Graph at 0x7f1db721e978>,
#  <networkx.classes.graph.Graph at 0x7f1db721e9e8>,
#  <networkx.classes.graph.Graph at 0x7f1db721ea58>,
#  <networkx.classes.graph.Graph at 0x7f1db721eac8>,
#  <networkx.classes.graph.Graph at 0x7f1db721eb38>,
#  <networkx.classes.graph.Graph at 0x7f1db721eba8>,
#  <networkx.classes.graph.Graph at 0x7f1db721ec18>,
#  <networkx.classes.graph.Graph at 0x7f1db721ec88>,
#  <networkx.classes.graph.Graph at 0x7f1db721ecf8>,
#  <networkx.classes.graph.Graph at 0x7f1db721ed68>,
#  <networkx.classes.graph.Graph at 0x7f1db721edd8>,
#  <networkx.classes.graph.Graph at 0x7f1db721ee48>,
#  <networkx.classes.graph.Graph at 0x7f1db721eeb8>,
#  <networkx.classes.graph.Graph at 0x7f1db721ef28>,
#  <networkx.classes.graph.Graph at 0x7f1db721ef98>,
#  <networkx.classes.graph.Graph at 0x7f1db950b048>,
#  <networkx.classes.graph.Graph at 0x7f1db950b0b8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b128>,
#  <networkx.classes.graph.Graph at 0x7f1db950b198>,
#  <networkx.classes.graph.Graph at 0x7f1db950b208>,
#  <networkx.classes.graph.Graph at 0x7f1db950b278>,
#  <networkx.classes.graph.Graph at 0x7f1db950b2e8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b358>,
#  <networkx.classes.graph.Graph at 0x7f1db950b3c8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b438>,
#  <networkx.classes.graph.Graph at 0x7f1db950b4a8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b518>,
#  <networkx.classes.graph.Graph at 0x7f1db950b588>,
#  <networkx.classes.graph.Graph at 0x7f1db950b5f8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b668>,
#  <networkx.classes.graph.Graph at 0x7f1db950b6d8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b748>,
#  <networkx.classes.graph.Graph at 0x7f1db950b7b8>,
#  <networkx.classes.graph.Graph at 0x7f1db950b828>,
#  <networkx.classes.graph.Graph at 0x7f1db950b898>,
#  <networkx.classes.graph.Graph at 0x7f1db950b908>,
#  <networkx.classes.graph.Graph at 0x7f1db950b978>,
#  <networkx.classes.graph.Graph at 0x7f1db950b9e8>,
#  <networkx.classes.graph.Graph at 0x7f1db950ba58>,
#  <networkx.classes.graph.Graph at 0x7f1db950bac8>,
#  <networkx.classes.graph.Graph at 0x7f1db950bb38>,
#  <networkx.classes.graph.Graph at 0x7f1db950bba8>,
#  <networkx.classes.graph.Graph at 0x7f1db950bc18>,
#  <networkx.classes.graph.Graph at 0x7f1db950bc88>,
#  <networkx.classes.graph.Graph at 0x7f1db950bcf8>,
#  <networkx.classes.graph.Graph at 0x7f1db950bd68>,
#  <networkx.classes.graph.Graph at 0x7f1db950bdd8>,
#  <networkx.classes.graph.Graph at 0x7f1db950be48>,
#  <networkx.classes.graph.Graph at 0x7f1db950beb8>,
#  <networkx.classes.graph.Graph at 0x7f1db950bf28>,
#  <networkx.classes.graph.Graph at 0x7f1db950bf98>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68048>,
#  <networkx.classes.graph.Graph at 0x7f1db7d680b8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68128>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68198>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68208>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68278>,
#  <networkx.classes.graph.Graph at 0x7f1db7d682e8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68358>,
#  <networkx.classes.graph.Graph at 0x7f1db7d683c8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68438>,
#  <networkx.classes.graph.Graph at 0x7f1db7d684a8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68518>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68588>,
#  <networkx.classes.graph.Graph at 0x7f1db7d685f8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68668>,
#  <networkx.classes.graph.Graph at 0x7f1db7d686d8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68748>,
#  <networkx.classes.graph.Graph at 0x7f1db7d687b8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68828>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68898>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68908>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68978>,
#  <networkx.classes.graph.Graph at 0x7f1db7d689e8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68a58>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68ac8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68b38>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68ba8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68c18>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68c88>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68cf8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68d68>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68dd8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68e48>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68eb8>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68f28>,
#  <networkx.classes.graph.Graph at 0x7f1db7d68f98>,
#  <networkx.classes.graph.Graph at 0x7f1db8060048>,
#  <networkx.classes.graph.Graph at 0x7f1db80600b8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060128>,
#  <networkx.classes.graph.Graph at 0x7f1db8060198>,
#  <networkx.classes.graph.Graph at 0x7f1db8060208>,
#  <networkx.classes.graph.Graph at 0x7f1db8060278>,
#  <networkx.classes.graph.Graph at 0x7f1db80602e8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060358>,
#  <networkx.classes.graph.Graph at 0x7f1db80603c8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060438>,
#  <networkx.classes.graph.Graph at 0x7f1db80604a8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060518>,
#  <networkx.classes.graph.Graph at 0x7f1db8060588>,
#  <networkx.classes.graph.Graph at 0x7f1db80605f8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060668>,
#  <networkx.classes.graph.Graph at 0x7f1db80606d8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060748>,
#  <networkx.classes.graph.Graph at 0x7f1db80607b8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060828>,
#  <networkx.classes.graph.Graph at 0x7f1db8060898>,
#  <networkx.classes.graph.Graph at 0x7f1db8060908>,
#  <networkx.classes.graph.Graph at 0x7f1db8060978>,
#  <networkx.classes.graph.Graph at 0x7f1db80609e8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060a58>,
#  <networkx.classes.graph.Graph at 0x7f1db8060ac8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060b38>,
#  <networkx.classes.graph.Graph at 0x7f1db8060ba8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060c18>,
#  <networkx.classes.graph.Graph at 0x7f1db8060c88>,
#  <networkx.classes.graph.Graph at 0x7f1db8060cf8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060d68>,
#  <networkx.classes.graph.Graph at 0x7f1db8060dd8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060e48>,
#  <networkx.classes.graph.Graph at 0x7f1db8060eb8>,
#  <networkx.classes.graph.Graph at 0x7f1db8060f28>,
#  <networkx.classes.graph.Graph at 0x7f1db8060f98>,
#  <networkx.classes.graph.Graph at 0x7f1db8367048>,
#  <networkx.classes.graph.Graph at 0x7f1db83670b8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367128>,
#  <networkx.classes.graph.Graph at 0x7f1db8367198>,
#  <networkx.classes.graph.Graph at 0x7f1db8367208>,
#  <networkx.classes.graph.Graph at 0x7f1db8367278>,
#  <networkx.classes.graph.Graph at 0x7f1db83672e8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367358>,
#  <networkx.classes.graph.Graph at 0x7f1db83673c8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367438>,
#  <networkx.classes.graph.Graph at 0x7f1db83674a8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367518>,
#  <networkx.classes.graph.Graph at 0x7f1db8367588>,
#  <networkx.classes.graph.Graph at 0x7f1db83675f8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367668>,
#  <networkx.classes.graph.Graph at 0x7f1db83676d8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367748>,
#  <networkx.classes.graph.Graph at 0x7f1db83677b8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367828>,
#  <networkx.classes.graph.Graph at 0x7f1db8367898>,
#  <networkx.classes.graph.Graph at 0x7f1db8367908>,
#  <networkx.classes.graph.Graph at 0x7f1db8367978>,
#  <networkx.classes.graph.Graph at 0x7f1db83679e8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367a58>,
#  <networkx.classes.graph.Graph at 0x7f1db8367ac8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367b38>,
#  <networkx.classes.graph.Graph at 0x7f1db8367ba8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367c18>,
#  <networkx.classes.graph.Graph at 0x7f1db8367c88>,
#  <networkx.classes.graph.Graph at 0x7f1db8367cf8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367d68>,
#  <networkx.classes.graph.Graph at 0x7f1db8367dd8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367e48>,
#  <networkx.classes.graph.Graph at 0x7f1db8367eb8>,
#  <networkx.classes.graph.Graph at 0x7f1db8367f28>,
#  <networkx.classes.graph.Graph at 0x7f1db8367f98>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7048>,
#  <networkx.classes.graph.Graph at 0x7f1db86e70b8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7128>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7198>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7208>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7278>,
#  <networkx.classes.graph.Graph at 0x7f1db86e72e8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7358>,
#  <networkx.classes.graph.Graph at 0x7f1db86e73c8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7438>,
#  <networkx.classes.graph.Graph at 0x7f1db86e74a8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7518>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7588>,
#  <networkx.classes.graph.Graph at 0x7f1db86e75f8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7668>,
#  <networkx.classes.graph.Graph at 0x7f1db86e76d8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7748>,
#  <networkx.classes.graph.Graph at 0x7f1db86e77b8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7828>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7898>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7908>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7978>,
#  <networkx.classes.graph.Graph at 0x7f1db86e79e8>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7a58>,
#  <networkx.classes.graph.Graph at 0x7f1db86e7ac8>]

# %%
H=graphs[0]

# %%
print (len(G)-len(H))
# Out:
# 869

# %%
print ("Check that the graph is now connected")
nx.number_connected_components(H)
# Out:
# Check that the graph is now connected
# 1

# %% [markdown]
# ## Global clustering coefficient

# %% [markdown]
# The global clustering coefficient measures the number of triangles in the network.

# %%
nx.triangles(G)
# Out:
# {84424: 210,
#  276: 54,
#  1662: 218,
#  5089: 1,
#  6058: 918,
#  6229: 107,
#  10639: 820,
#  16442: 137,
#  19325: 828,
#  19834: 3,
#  20113: 44,
#  21937: 13,
#  25452: 1906,
#  26902: 3,
#  29829: 11,
#  30222: 506,
#  32432: 128,
#  33040: 2759,
#  39238: 16,
#  39521: 1793,
#  41418: 487,
#  45009: 2384,
#  45098: 189,
#  45242: 702,
#  47005: 27,
#  47968: 5646,
#  47999: 148,
#  49934: 360,
#  50220: 44,
#  50897: 1594,
#  51730: 1,
#  53681: 23,
#  57537: 10,
#  58458: 10,
#  59326: 158,
#  61571: 354,
#  63552: 934,
#  64124: 76,
#  64568: 1587,
#  66200: 73,
#  69839: 101,
#  72391: 11,
#  73543: 537,
#  76259: 205,
#  77098: 423,
#  77915: 8,
#  78627: 396,
#  83560: 1145,
#  85420: 236,
#  88768: 15,
#  89131: 6,
#  89308: 117,
#  89994: 72,
#  90506: 121,
#  91060: 236,
#  92387: 32,
#  93296: 143,
#  94138: 513,
#  94329: 113,
#  95070: 11,
#  95531: 285,
#  96570: 114,
#  97101: 32,
#  98506: 491,
#  99104: 3003,
#  104802: 1907,
#  106611: 526,
#  107829: 412,
#  109016: 29,
#  112605: 623,
#  117751: 41,
#  122908: 295,
#  124023: 89,
#  125190: 1,
#  130825: 42,
#  132445: 1246,
#  560: 3,
#  15829: 50,
#  42972: 1001,
#  55528: 1,
#  57618: 142,
#  60310: 1,
#  63707: 90,
#  63769: 110,
#  68320: 22,
#  75607: 780,
#  92552: 650,
#  93762: 68,
#  93889: 29,
#  95860: 49,
#  96909: 41,
#  99870: 1409,
#  112293: 84,
#  113138: 1104,
#  116343: 45,
#  116453: 104,
#  118859: 233,
#  121831: 111,
#  122003: 5,
#  123268: 28,
#  125345: 172,
#  127886: 5187,
#  129530: 187,
#  129910: 45,
#  132104: 57,
#  2175: 9,
#  3365: 1081,
#  4279: 7,
#  4930: 41,
#  5335: 3028,
#  8445: 46,
#  9039: 378,
#  10976: 4324,
#  11050: 73,
#  11580: 12,
#  19204: 1930,
#  23986: 6157,
#  24075: 969,
#  26526: 58,
#  28516: 4399,
#  28787: 486,
#  31404: 5,
#  33777: 13,
#  34608: 6711,
#  35729: 71,
#  36907: 5282,
#  37861: 0,
#  38921: 1102,
#  42512: 11,
#  42994: 1248,
#  44011: 122,
#  46847: 2251,
#  47856: 2318,
#  50991: 0,
#  52870: 30,
#  53890: 1201,
#  55233: 462,
#  56117: 108,
#  58532: 17,
#  59151: 1000,
#  59173: 79,
#  60390: 378,
#  61461: 1429,
#  61472: 4,
#  61686: 543,
#  61929: 147,
#  62496: 555,
#  64054: 4975,
#  65114: 1377,
#  65794: 20,
#  66766: 14,
#  68639: 195,
#  69582: 999,
#  70618: 548,
#  72233: 386,
#  72941: 1590,
#  74612: 18,
#  77580: 629,
#  79936: 187,
#  83003: 642,
#  84150: 0,
#  87214: 1003,
#  87237: 130,
#  92504: 7,
#  94235: 6826,
#  95822: 2152,
#  101953: 196,
#  105827: 110,
#  110499: 23,
#  112243: 0,
#  115344: 35,
#  118103: 1133,
#  118630: 382,
#  118958: 51,
#  120454: 400,
#  126152: 81,
#  130165: 380,
#  63225: 42,
#  2969: 1,
#  8744: 28,
#  19113: 41,
#  20188: 0,
#  23579: 11,
#  26065: 15,
#  27281: 76,
#  30400: 18,
#  30864: 19,
#  39902: 166,
#  42077: 5,
#  49633: 1,
#  57772: 1052,
#  59444: 10,
#  65213: 7,
#  69459: 3,
#  99504: 15,
#  104589: 479,
#  106833: 85,
#  110210: 430,
#  113335: 15,
#  118286: 10,
#  120586: 32,
#  121399: 1832,
#  121988: 68,
#  122460: 18,
#  127393: 216,
#  4526: 11,
#  15406: 142,
#  17485: 376,
#  22055: 8,
#  25095: 132,
#  26713: 1541,
#  29421: 599,
#  31334: 1369,
#  38861: 193,
#  39298: 1954,
#  40400: 2,
#  43227: 685,
#  45858: 131,
#  51604: 3,
#  51631: 586,
#  52480: 59,
#  55508: 120,
#  65713: 2256,
#  66511: 516,
#  67988: 154,
#  68577: 106,
#  68629: 28,
#  69935: 82,
#  70637: 853,
#  71296: 58,
#  71722: 2,
#  78060: 409,
#  78070: 357,
#  79077: 8,
#  86411: 429,
#  91401: 1762,
#  92357: 1405,
#  93661: 23,
#  98621: 822,
#  100099: 1666,
#  102617: 1939,
#  106954: 21,
#  107534: 671,
#  107797: 320,
#  107933: 260,
#  112779: 206,
#  112903: 22,
#  115420: 205,
#  117953: 875,
#  123695: 62,
#  124913: 238,
#  131639: 55,
#  132766: 2,
#  106274: 3070,
#  811: 490,
#  1086: 3006,
#  2158: 1880,
#  3335: 36,
#  4239: 4132,
#  5099: 33,
#  5866: 888,
#  5959: 422,
#  6358: 859,
#  6540: 231,
#  7026: 859,
#  8381: 846,
#  8583: 1922,
#  8833: 2055,
#  10426: 1493,
#  12203: 269,
#  13219: 410,
#  14651: 922,
#  14859: 1637,
#  15223: 506,
#  16043: 351,
#  16400: 921,
#  16434: 1068,
#  17549: 36,
#  17756: 196,
#  18007: 610,
#  18344: 36,
#  19383: 1927,
#  20296: 948,
#  21192: 554,
#  21718: 8186,
#  21728: 843,
#  21729: 171,
#  22070: 683,
#  27862: 2529,
#  28128: 1769,
#  28210: 1460,
#  29606: 1489,
#  30422: 22,
#  30502: 496,
#  30625: 535,
#  32595: 473,
#  33659: 36,
#  34945: 635,
#  35290: 7065,
#  35302: 91,
#  35638: 153,
#  36814: 1067,
#  37179: 1007,
#  38109: 9008,
#  38898: 447,
#  38966: 4793,
#  39696: 2308,
#  40649: 289,
#  40745: 207,
#  41473: 1005,
#  42366: 899,
#  42551: 1820,
#  43850: 1835,
#  44022: 36,
#  44183: 1441,
#  44237: 198,
#  47128: 1119,
#  48423: 582,
#  49689: 902,
#  51306: 601,
#  51587: 1164,
#  51588: 253,
#  52412: 740,
#  52682: 4197,
#  53056: 362,
#  53213: 11269,
#  55066: 363,
#  55085: 919,
#  55999: 1880,
#  56361: 104,
#  57961: 844,
#  60088: 893,
#  60471: 2212,
#  61892: 25,
#  62459: 834,
#  66006: 540,
#  67410: 3315,
#  67670: 252,
#  67716: 1894,
#  68363: 2270,
#  69493: 676,
#  70950: 839,
#  71801: 1401,
#  72114: 109,
#  72380: 402,
#  74225: 153,
#  74361: 926,
#  75690: 2223,
#  76706: 1521,
#  76749: 2673,
#  76854: 1537,
#  77019: 1105,
#  77152: 193,
#  77208: 579,
#  79379: 346,
#  80218: 499,
#  80782: 964,
#  82347: 777,
#  82704: 2003,
#  84122: 4490,
#  86202: 1995,
#  86721: 829,
#  87325: 1322,
#  88348: 407,
#  89588: 1213,
#  89969: 1200,
#  93101: 380,
#  93271: 2154,
#  94560: 35,
#  95036: 2947,
#  95261: 28,
#  95911: 1330,
#  96786: 462,
#  97012: 89,
#  99023: 1835,
#  99239: 2134,
#  100394: 2275,
#  100461: 867,
#  100717: 820,
#  102653: 621,
#  103169: 1306,
#  104241: 598,
#  105680: 3343,
#  106763: 1432,
#  107846: 1397,
#  108722: 302,
#  109056: 253,
#  111385: 1950,
#  111660: 1041,
#  111709: 2061,
#  112157: 2382,
#  112695: 1113,
#  112848: 1861,
#  113726: 858,
#  113825: 671,
#  114249: 954,
#  115209: 3395,
#  115281: 206,
#  115607: 3644,
#  115700: 307,
#  116194: 21,
#  116337: 1529,
#  118896: 779,
#  119042: 36,
#  119664: 1682,
#  120199: 1889,
#  120618: 2541,
#  121461: 465,
#  122425: 1180,
#  122495: 827,
#  123233: 485,
#  125226: 871,
#  125267: 824,
#  125557: 338,
#  125678: 1090,
#  125766: 77,
#  125774: 312,
#  126948: 643,
#  127225: 259,
#  127274: 455,
#  127816: 670,
#  129273: 1271,
#  129410: 899,
#  129483: 509,
#  131234: 940,
#  131592: 820,
#  1513: 28,
#  4851: 332,
#  4893: 36,
#  6256: 1654,
#  11727: 56,
#  12494: 117,
#  14382: 17,
#  18042: 42,
#  26219: 853,
#  27124: 284,
#  31235: 180,
#  33883: 362,
#  35703: 117,
#  37378: 1291,
#  41567: 397,
#  43405: 152,
#  48115: 464,
#  48267: 184,
#  54771: 1512,
#  65484: 116,
#  65610: 54,
#  68921: 540,
#  79758: 100,
#  82866: 179,
#  87294: 2594,
#  92001: 195,
#  95855: 6,
#  101422: 47,
#  105901: 710,
#  106176: 425,
#  107608: 197,
#  108944: 189,
#  111957: 723,
#  112410: 37,
#  119031: 529,
#  119480: 412,
#  121026: 1868,
#  124998: 106,
#  125365: 696,
#  128934: 36,
#  131519: 77,
#  131914: 94,
#  132206: 646,
#  2689: 276,
#  2760: 276,
#  4148: 525,
#  6374: 38,
#  6934: 78,
#  10767: 47,
#  15921: 431,
#  15973: 870,
#  16035: 446,
#  18257: 81,
#  18505: 79,
#  20775: 145,
#  22036: 78,
#  23453: 3468,
#  23638: 279,
#  26849: 82,
#  29228: 78,
#  31097: 88,
#  31931: 78,
#  37918: 206,
#  38977: 282,
#  42886: 679,
#  43737: 168,
#  44244: 286,
#  47735: 140,
#  54608: 320,
#  59069: 518,
#  60427: 15,
#  68381: 727,
#  82214: 297,
#  93583: 276,
#  93984: 327,
#  95072: 6,
#  97387: 373,
#  101326: 4,
#  101994: 780,
#  112383: 285,
#  115063: 276,
#  117676: 442,
#  118912: 875,
#  121209: 91,
#  128878: 276,
#  131320: 489,
#  17737: 0,
#  9648: 4,
#  16793: 0,
#  27573: 7,
#  28827: 3,
#  37818: 1,
#  54011: 6,
#  56224: 1,
#  71157: 11,
#  87601: 0,
#  119665: 1,
#  122165: 1,
#  122336: 1,
#  130188: 1,
#  47255: 5,
#  38313: 30,
#  50634: 1,
#  76014: 23,
#  76026: 635,
#  84047: 3,
#  86017: 0,
#  103432: 1,
#  109229: 180,
#  122293: 1,
#  130391: 195,
#  48541: 3,
#  48546: 502,
#  58486: 531,
#  58719: 22,
#  64569: 1,
#  71627: 8,
#  73308: 23,
#  80089: 58,
#  80534: 3,
#  84851: 843,
#  86063: 3,
#  93360: 214,
#  116725: 3,
#  116919: 13,
#  1968: 184,
#  17447: 264,
#  29301: 283,
#  36197: 239,
#  43161: 153,
#  43731: 153,
#  56031: 490,
#  57916: 153,
#  61859: 8,
#  62844: 153,
#  63840: 11,
#  72171: 3,
#  78024: 471,
#  79455: 477,
#  85941: 6,
#  85993: 3,
#  95051: 163,
#  95109: 169,
#  99717: 1034,
#  110812: 235,
#  111014: 175,
#  111916: 7,
#  117311: 6,
#  122105: 159,
#  122740: 197,
#  124653: 166,
#  130921: 24,
#  17097: 821,
#  1500: 212,
#  3377: 618,
#  3420: 1331,
#  5088: 353,
#  5665: 941,
#  6331: 436,
#  7520: 373,
#  8332: 573,
#  8912: 257,
#  9103: 1331,
#  10479: 728,
#  12600: 564,
#  14783: 547,
#  16042: 522,
#  18553: 529,
#  19695: 527,
#  20598: 1220,
#  21333: 19,
#  22767: 1767,
#  22833: 656,
#  34097: 285,
#  35020: 1177,
#  35452: 171,
#  39597: 637,
#  46229: 1198,
#  54239: 698,
#  63399: 21,
#  65895: 22,
#  70035: 560,
#  71482: 869,
#  71602: 736,
#  73216: 668,
#  73714: 59,
#  75761: 530,
#  76529: 329,
#  76830: 708,
#  77194: 673,
#  78328: 1348,
#  78777: 364,
#  78800: 519,
#  79552: 1334,
#  91772: 234,
#  91787: 140,
#  91843: 954,
#  93530: 652,
#  94267: 200,
#  95558: 787,
#  96429: 368,
#  97491: 671,
#  97815: 606,
#  100548: 523,
#  104544: 913,
#  105528: 929,
#  105725: 42,
#  107436: 1048,
#  110773: 75,
#  114530: 1984,
#  120321: 650,
#  123670: 1027,
#  131704: 1718,
#  133062: 970,
#  97966: 3,
#  18877: 1,
#  33380: 12,
#  80396: 3,
#  84299: 30,
#  108170: 22,
#  112976: 2,
#  12890: 34,
#  23769: 17,
#  31638: 87,
#  39339: 9,
#  51539: 33,
#  61974: 42,
#  87885: 211,
#  123201: 41,
#  5412: 3,
#  20664: 14,
#  39978: 0,
#  110535: 3,
#  13353: 55,
#  242: 3,
#  680: 21,
#  1418: 6,
#  14706: 10,
#  17837: 2421,
#  24682: 81,
#  26624: 27,
#  29131: 6,
#  30601: 2,
#  30614: 9,
#  34051: 39,
#  35317: 14,
#  38226: 61,
#  42327: 2,
#  45826: 1,
#  46803: 1,
#  50264: 14,
#  52497: 3,
#  56970: 1,
#  58023: 40,
#  60078: 1,
#  68322: 6,
#  68830: 8,
#  68950: 284,
#  70804: 4,
#  71583: 3,
#  72370: 125,
#  72441: 3,
#  72444: 2,
#  74787: 122,
#  75665: 3,
#  78370: 1,
#  80482: 3,
#  80823: 2,
#  80960: 5,
#  82947: 27,
#  83877: 1,
#  88082: 69,
#  92276: 5,
#  96326: 23,
#  98853: 111,
#  100536: 39,
#  109585: 2,
#  109894: 63,
#  112256: 12,
#  120094: 3,
#  120169: 4,
#  127688: 4,
#  131741: 4,
#  132492: 1480,
#  132691: 2,
#  13640: 2,
#  26731: 4,
#  28273: 3,
#  47881: 3,
#  59716: 27,
#  68758: 4,
#  74685: 1,
#  92281: 3,
#  93585: 3,
#  97683: 15,
#  113717: 8,
#  119757: 4,
#  123558: 3,
#  118675: 36,
#  4932: 139,
#  8053: 702,
#  11020: 17,
#  12924: 214,
#  35111: 67,
#  38185: 18,
#  44467: 150,
#  48243: 18,
#  57276: 13,
#  58633: 79,
#  65657: 19,
#  75731: 115,
#  79176: 17,
#  105955: 40,
#  113867: 39,
#  125136: 61,
#  8546: 35,
#  9522: 7,
#  18079: 97,
#  20129: 3,
#  23626: 2776,
#  50316: 27,
#  55462: 56,
#  55675: 13,
#  59052: 19,
#  67060: 327,
#  67618: 1006,
#  70981: 0,
#  76641: 3,
#  86126: 11,
#  87760: 48,
#  101610: 166,
#  107618: 25,
#  109192: 17,
#  114995: 0,
#  120732: 167,
#  122852: 91,
#  128685: 1229,
#  291: 196,
#  3998: 107,
#  4959: 1329,
#  6619: 21,
#  12328: 1600,
#  16693: 69,
#  25625: 1,
#  26474: 3,
#  34218: 23,
#  34862: 1525,
#  34928: 8,
#  38868: 4,
#  41140: 271,
#  47237: 1487,
#  55155: 1746,
#  57559: 26,
#  57974: 4,
#  61750: 6,
#  66826: 1406,
#  71861: 3,
#  75546: 30,
#  83393: 21,
#  85862: 2,
#  86460: 236,
#  90269: 21,
#  91858: 28,
#  95291: 4,
#  95680: 39,
#  97431: 1095,
#  97788: 108,
#  99613: 32,
#  101271: 21,
#  102475: 0,
#  102874: 95,
#  104466: 6,
#  106392: 152,
#  110670: 109,
#  111496: 2053,
#  114677: 1350,
#  128657: 230,
#  128732: 1095,
#  129683: 908,
#  130919: 36,
#  24527: 108,
#  25831: 16,
#  28623: 784,
#  30018: 29,
#  37519: 28,
#  43765: 1065,
#  44674: 77,
#  56205: 27,
#  68941: 308,
#  91247: 0,
#  94743: 78,
#  98712: 32,
#  118945: 14,
#  59946: 46,
#  66875: 91,
#  126260: 1,
#  35690: 781,
#  2478: 1771,
#  2736: 2355,
#  4679: 1988,
#  4786: 3053,
#  5746: 1,
#  5979: 325,
#  6387: 366,
#  7208: 331,
#  8978: 524,
#  9049: 28,
#  11513: 1267,
#  14149: 3544,
#  16884: 55,
#  24128: 353,
#  25329: 3834,
#  27242: 69,
#  33351: 1806,
#  37907: 2231,
#  38413: 2206,
#  40208: 748,
#  44790: 222,
#  45732: 906,
#  47674: 490,
#  49486: 3361,
#  50163: 581,
#  50808: 5103,
#  53219: 360,
#  54681: 3936,
#  55554: 3,
#  55602: 1997,
#  56184: 314,
#  56302: 1018,
#  61574: 3,
#  65337: 4088,
#  70366: 1487,
#  71040: 3067,
#  77480: 3423,
#  77999: 605,
#  79811: 573,
#  80988: 175,
#  83171: 1845,
#  85668: 55,
#  85740: 3538,
#  92810: 619,
#  93624: 2092,
#  96525: 144,
#  97471: 190,
#  99798: 18,
#  100181: 580,
#  100237: 156,
#  101520: 445,
#  105651: 296,
#  108958: 609,
#  111161: 6457,
#  112453: 375,
#  113591: 1093,
#  117816: 26,
#  121653: 51,
#  121655: 15,
#  124529: 2813,
#  126451: 868,
#  126916: 3154,
#  128381: 325,
#  128985: 36,
#  129458: 595,
#  130997: 5373,
#  1155: 2522,
#  1324: 3217,
#  1334: 484,
#  1663: 1540,
#  1776: 3330,
#  2094: 3232,
#  5453: 1555,
#  6443: 231,
#  6548: 370,
#  7083: 1614,
#  7205: 3755,
#  7264: 3115,
#  8273: 3856,
#  8305: 190,
#  9048: 360,
#  10914: 1276,
#  11799: 5596,
#  19066: 2289,
#  19674: 1002,
#  21530: 527,
#  21560: 442,
#  23457: 171,
#  25850: 409,
#  28577: 2580,
#  29489: 1492,
#  32202: 1386,
#  34110: 791,
#  36781: 1471,
#  36833: 1524,
#  37479: 4185,
#  39264: 992,
#  40242: 1416,
#  40495: 2257,
#  41554: 1533,
#  42092: 1529,
#  43051: 511,
#  43601: 2369,
#  44434: 1976,
#  44785: 3365,
#  45637: 549,
#  46415: 1408,
#  48507: 1149,
#  48703: 3163,
#  49258: 1550,
#  51121: 687,
#  51697: 2516,
#  56221: 1516,
#  56933: 2531,
#  57156: 4234,
#  58278: 3683,
#  58926: 218,
#  59843: 1030,
#  59861: 2980,
#  60211: 1684,
#  60576: 1540,
#  62842: 379,
#  62855: 1540,
#  64374: 1276,
#  66522: 409,
#  66553: 933,
#  67299: 3944,
#  67755: 253,
#  70099: 967,
#  70339: 1540,
#  73589: 2300,
#  74570: 3857,
#  75947: 6515,
#  77373: 441,
#  80186: 3383,
#  80187: 171,
#  80429: 436,
#  80561: 1542,
#  82020: 0,
#  83351: 4834,
#  85009: 1667,
#  88155: 1794,
#  92092: 1036,
#  92790: 8357,
#  95179: 1515,
#  95765: 3312,
#  95934: 979,
#  97249: 4756,
#  97320: 3357,
#  99086: 1868,
#  99131: 105,
#  99539: 1579,
#  99825: 1804,
#  100621: 3,
#  100930: 1373,
#  101167: 3414,
#  101641: 312,
#  102282: 414,
#  103290: 714,
#  104749: 2372,
#  105049: 2917,
#  106945: 1057,
#  107877: 3566,
#  110402: 1379,
#  114352: 2914,
#  115480: 3788,
#  115796: 153,
#  115900: 4620,
#  119515: 3029,
#  122753: 190,
#  122787: 3086,
#  125954: 2915,
#  126258: 85,
#  128641: 1004,
#  130519: 2973,
#  130853: 2973,
#  131221: 2488,
#  ...}

# %% [markdown]
# How many triangles there are in the whole network?

# %%
float(sum(list(nx.triangles(G).values())))/3
# Out:
# 1351441.0

# %% [markdown]
# The global clustering coefficient is
# <center>
# $C_\Delta = \frac{3 \times \text{triangles}}{\text{triplets}}$
# </center>

# %%
nx.transitivity(G)
# Out:
# 0.3180015812533629

# %% [markdown]
# ## Average clustering coefficient
# As an alternative to the global clustering coefficient, the overall level of clustering in a network is measured by Watts and Strogatz as the average of the local clustering coefficients of all the vertices $n$:
#
# <center>
# $\bar{C} = \frac{1}{n}\sum_{i=1}^{n} C_i.$
# </center>
#
# It is worth noting that this metric places more weight on the low degree nodes, while the transitivity ratio places more weight on the high degree nodes. In fact, a weighted average where each local clustering score is weighted by $k_i(k_i-1)$ is identical to the global clustering coefficient.

# %%
print ("The average clustering coefficient of G is")
nx.average_clustering(G)
# Out:
# The average clustering coefficient of G is
# 0.6305932411707943

# %% [markdown]
# ## Average shortest path length
# #### Warning! Calculating the shortest paths is intensive!

# %% [markdown]
# The graph is small world.

# %%
nx.average_shortest_path_length(H)
# Out:
# 4.194011768617203

# %%
math.log(len(G))
# Out:
# 9.840121676914308

# %% [markdown]
# ### Compare the results with a random ER network

# %% [markdown]
# We generate a random Erdos-Renyi graph with same average connectivity of H.

# %%
nnodes=18000
plink=0.00122

ER=nx.fast_gnp_random_graph(nnodes, plink)

# %%
nx.is_connected(ER)
# Out:
# True

# %%
print ("The ER graph has", len(ER), "nodes")
print ("and",len(ER.edges()),"edges")
# Out:
# The ER graph has 18000 nodes
# and 197519 edges

# %%
print ("The average clustering coefficient of ER is")
nx.average_clustering(ER)
# Out:
# The average clustering coefficient of ER is
# 0.0012088225099030822

# %%
print (float(sum(list(nx.triangles(ER).values())))/3)
# Out:
# 1766.0

# %% [markdown]
# The ER graph is also small world.

# %%
nx.average_shortest_path_length(ER)
# Out:
# 3.5206575797420845

# %% [markdown]
# ### Compare the results with a random AB network

# %%
AB=nx.barabasi_albert_graph(18000,11)

# %%
print ("The AB graph has", len(AB), "nodes")
print ("and",len(AB.edges()),"edges")
# Out:
# The AB graph has 18000 nodes
# and 197879 edges

# %%
from collections import Counter 
degrees=list(AB.degree().values())
c=Counter(degrees)

# %%
import powerlaw as pwl

# %%
plt.figure(figsize=(10,7))
x=[]
y=[]
for i in sorted(c):   
    x.append(i)
    y.append(float(c[i])/len(AB))

    
plt.plot(np.array(x),np.array(y))
pwl.plot_pdf(degrees)

plt.xlabel('$k$', fontsize=18)
plt.ylabel('$P(k)$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([10,1000,0.0000001,1])
plt.show()

# %%
fit_function = pwl.Fit(degrees, xmin=11)
# Out:
# /home/carlo/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
fit_function.power_law.alpha
# Out:
# /home/carlo/anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# 3.0526154625039936

# %%
fit_function.power_law.sigma
# Out:
# 0.015299292352753669

# %%
fit_function.power_law.xmin
# Out:
# 11.0

# %%
print ("The average clustering coefficient of AB is")
nx.average_clustering(AB)
# Out:
# The average clustering coefficient of AB is
# 0.007404411835038909

# %%
print ("The number of triangles is ", float(sum(list(nx.triangles(AB).values())))/3.0)
# Out:
# The number of triangles is  22574.0

# %% [markdown]
# The AB network is small world

# %%
nx.average_shortest_path_length(AB)
# Out:
# 3.13407395472588

# %% [markdown]
# ### Compare the results with a random WS network

# %%
WS=nx.connected_watts_strogatz_graph(18000,23,0.2,50)

# %%
print ("The WS graph has", len(WS), "nodes")
print ("and",len(WS.edges()),"edges")
# Out:
# The WS graph has 18000 nodes
# and 198000 edges

# %%
nx.is_connected(WS)
# Out:
# True

# %%
ws_degrees=list(WS.degree().values())

# %%
plt.figure(figsize=(10,7))
plt.hist(ws_degrees, bins=10)
plt.xlabel('$k$', fontsize=18)
plt.ylabel('$Freq.$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([    0.,  1000.,  2000.,  3000.,  4000.,  5000.,  6000.,  7000.,
#          8000.]), <a list of 9 Text yticklabel objects>)

# %%
print ("The average clustering coefficient of WS is")
nx.average_clustering(WS)
# Out:
# The average clustering coefficient of WS is
# 0.3695840973874992

# %%
nx.average_shortest_path_length(WS)
# Out:
# 4.03575967183362

# %% [markdown]
# ## Closeness Centrality

# %% [markdown]
# In connected graphs there is a natural distance metric between all pairs of nodes, defined by the length of their shortest paths.
# The '''farness''' of a node ''x'' is defined as the sum of its distances from all other nodes, and its closeness was defined by Bavelas as the reciprocal of the farness that is:
#
#
# <center>
# $C(x)= \frac{1}{\sum_y d(y,x)}.$
# </center>
#
#
# Thus, the more central a node is the lower its total distance from all other nodes. Note that taking distances ''from'' or ''to'' all other nodes is irrelevant in undirected graphs, whereas in directed graphs distances ''to'' a node are considered a more meaningful measure of centrality, as in general (e.g., in, the web) a node has little control over its incoming links.

# %% [markdown]
# #### Be careful! Computing all the distances between pair of nodes can be intensive.

# %%
close_centr=nx.closeness_centrality(G)

# %%
print (close_centr)
# Out:
# {84424: 0.29143162289216096, 276: 0.2610825182052537, 1662: 0.2768661855076437, 5089: 0.22535050348474, 6058: 0.2931580246143367, 6229: 0.27250459188728965, 10639: 0.29973017442355177, 16442: 0.27194033728102124, 19325: 0.2986448983804922, 19834: 0.235548062242379, 20113: 0.2682529961900883, 21937: 0.24865255225542662, 25452: 0.30098246267984763, 26902: 0.22549634407790312, 29829: 0.24941172459628888, 30222: 0.28993700022950036, 32432: 0.28044531275997236, 33040: 0.31822762288707307, 39238: 0.2510141610996421, 39521: 0.3014128627129856, 41418: 0.2583252162971972, 45009: 0.30248086945493513, 45098: 0.27342104311955473, 45242: 0.2854577862483591, 47005: 0.24676933810563192, 47968: 0.3163466777008404, 47999: 0.2679456707656171, 49934: 0.2871573969912937, 50220: 0.27091764829442017, 50897: 0.3045799695926208, 51730: 0.22324368047692614, 53681: 0.23943945299087524, 57537: 0.25003632229858613, 58458: 0.23086595804787308, 59326: 0.27904730314321324, 61571: 0.2889018088145652, 63552: 0.30056387218354974, 64124: 0.27514834886648654, 64568: 0.29618913303461575, 66200: 0.26042144898588093, 69839: 0.2821088928538394, 72391: 0.24618933230734474, 73543: 0.2949559497532022, 76259: 0.2798156253362128, 77098: 0.2837923271806379, 77915: 0.23943273725601075, 78627: 0.27978352744890217, 83560: 0.2960504629012374, 85420: 0.2740002599142103, 88768: 0.24169009775504816, 89131: 0.2345932863710786, 89308: 0.26560305837672654, 89994: 0.2693915804710598, 90506: 0.27247414930600633, 91060: 0.28057435696232363, 92387: 0.26266912099439005, 93296: 0.27558359071416005, 94138: 0.2924199327837899, 94329: 0.2682234960726809, 95070: 0.24965607784395216, 95531: 0.2766687764627185, 96570: 0.26270145397846406, 97101: 0.26621184076331367, 98506: 0.29052410699056197, 99104: 0.2911334526211438, 104802: 0.3005321280674944, 106611: 0.2854148380199327, 107829: 0.276283743211767, 109016: 0.2608989944302316, 112605: 0.29605559651657487, 117751: 0.25959388458870225, 122908: 0.24958673501614417, 124023: 0.2616346419565152, 125190: 0.231910217271317, 130825: 0.26592988061920747, 132445: 0.29936754038179864, 560: 0.22946039560673007, 15829: 0.2578180996574304, 42972: 0.2668484424362601, 55528: 0.22707689089223346, 57618: 0.260119906690145, 60310: 0.22369998421836898, 63707: 0.24678360573427513, 63769: 0.251235784327065, 68320: 0.2417790865328097, 75607: 0.2914764011184696, 92552: 0.29185507778789993, 93762: 0.24914966867341387, 93889: 0.24916421288804116, 95860: 0.24091593096340175, 96909: 0.24453558766975117, 99870: 0.29961445661087954, 112293: 0.2532556581697598, 113138: 0.28755882632702334, 116343: 0.23217197051163846, 116453: 0.24822957539276472, 118859: 0.2804775626809429, 121831: 0.2516060273150059, 122003: 0.25819239324190724, 123268: 0.2330625504465758, 125345: 0.2780203581747982, 127886: 0.3205036642672115, 129530: 0.27704139736664707, 129910: 0.23217197051163846, 132104: 0.244081119036932, 2175: 0.23178428177456364, 3365: 0.29836307420992186, 4279: 0.24156699061242493, 4930: 0.2542399588336414, 5335: 0.3019939894846442, 8445: 0.24987165138031783, 9039: 0.28139285683347653, 10976: 0.314250509764667, 11050: 0.26743781634577624, 11580: 0.24954660677191864, 19204: 0.3053152753132038, 23986: 0.3267916584460591, 24075: 0.2904104472786929, 26526: 0.2655782692537272, 28516: 0.3194721416772268, 28787: 0.28318510856716467, 31404: 0.23594845488549415, 33777: 0.24884100502127002, 34608: 0.3272614566899436, 35729: 0.276064842679511, 36907: 0.31946616386644383, 37861: 0.22380261637650398, 38921: 0.29403651417401805, 42512: 0.24256571186762077, 42994: 0.3017644702095224, 44011: 0.276337404433419, 46847: 0.3126907967896991, 47856: 0.30857651856195406, 50991: 0.22380261637650398, 52870: 0.24592337335994752, 53890: 0.2936723634778946, 55233: 0.28659342647700065, 56117: 0.2796323079716057, 58532: 0.2454249230301348, 59151: 0.2900897153260446, 59173: 0.2657849867757579, 60390: 0.2727396635012438, 61461: 0.28982871928285386, 61472: 0.24260362622400508, 61686: 0.2816899883767424, 61929: 0 ...

# %% [markdown]
# ## Measure the assortativity of the network

# %% [markdown]
# Assortativity can be measured in different ways. A simple approach is measuring the average nearest neighbor degree to assess the level of degree-assortativity.

# %%
from collections import defaultdict

# %%
x=[]
y=[]

avg_knn=defaultdict(list)

for n in G.nodes():
    k=G.degree(n)
    
    nn=len(G.neighbors(n))
    total=0
    for j in G.neighbors(n):
        total+=G.degree(j)
    
    avg_knn[k].append(float(total)/nn)
    
    x.append(k)
    y.append(float(total)/nn)

# %%
plt.figure(figsize=(10,7))
plt.scatter(x,y)

plt.xlabel('$k_i$', fontsize=18)
plt.ylabel('$k_{nn}$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([0.1,1000,1,1000])
plt.show()

# %%
z=[]
for k in avg_knn:
    knn=np.array(avg_knn[k])
    z.append(np.average(knn))
    #print k, np.average(knn)

# %%
plt.figure(figsize=(10,7))
plt.scatter(x,y)
plt.plot(list(avg_knn.keys()),z, color='r')

plt.xlabel('$k_i$', fontsize=18)
plt.ylabel('$k_{nn}$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([0.1,1000,1,1000])
plt.show()

# %%
r=nx.degree_assortativity_coefficient(G)

# %%
print (r)
# Out:
# 0.205120678986

# %% [markdown]
# The degree assortativity coefficient of a ER graph is much smaller.

# %%
ERr=nx.degree_assortativity_coefficient(ER)

# %%
ERr
# Out:
# -0.00023544329422853254

# %% [markdown]
# NetworkX offers a number of functions to compute the same quantity.

# %%
knn_avg2=nx.average_degree_connectivity(G)

# %%
print (knn_avg2)
# Out:
# {75: 77.99882352941177, 31: 58.04037897586284, 43: 69.43556771545828, 2: 23.927865037812683, 90: 77.11203703703704, 42: 60.331389698736636, 118: 78.43502824858757, 30: 57.107625272331155, 113: 80.56814159292036, 3: 28.27523510971787, 28: 58.709793351302785, 8: 39.26327433628319, 158: 86.37341772151899, 13: 44.994888023369036, 77: 73.6357733175915, 36: 62.516007532956685, 257: 86.91439688715953, 12: 42.094705443698736, 134: 89.48258706467662, 55: 78.45880077369439, 171: 82.84210526315789, 86: 81.7296511627907, 15: 48.993356242840775, 274: 96.15328467153284, 47: 67.27006769825918, 91: 80.11648351648351, 22: 49.707849419303166, 150: 90.85555555555555, 14: 44.20594010800196, 6: 35.63912864775997, 52: 71.10063224446786, 67: 75.60914179104478, 108: 87.86516203703704, 27: 60.657407407407405, 142: 87.4906103286385, 62: 64.69180470793374, 7: 37.66788247213779, 61: 76.44262295081967, 49: 68.4408811143505, 132: 81.35950413223141, 41: 67.15829746532759, 5: 33.02613981762918, 32: 61.44760338345865, 20: 46.04779411764706, 50: 65.12612903225806, 56: 74.32245879120879, 18: 50.58738425925926, 44: 67.23400673400674, 81: 81.11552028218695, 9: 39.82104805392477, 84: 76.93650793650794, 123: 86.35040650406503, 120: 94.29166666666667, 82: 70.11293743372217, 59: 80.08916728076639, 10: 40.97029288702929, 109: 80.96238532110091, 21: 52.61680378957866, 72: 76.99714052287581, 33: 62.90030303030303, 103: 76.49393203883496, 93: 81.32453567937439, 19: 47.950607287449394, 60: 74.33186274509804, 48: 63.18070652173913, 222: 101.52477477477477, 40: 62.843686868686866, 154: 103.51298701298701, 66: 70.86293164200141, 220: 106.10909090909091, 24: 50.449945887445885, 152: 91.66973684210527, 323: 97.31424148606811, 115: 81.92028985507247, 34: 62.29171668667467, 271: 96.6309963099631, 53: 73.98842767295598, 4: 28.074249605055293, 336: 98.73214285714286, 297: 89.98653198653199, 1: 26.308352849336455, 89: 69.29775280898876, 25: 54.5074358974359, 175: 98.65904761904761, 162: 88.1358024691358, 16: 46.23848684210526, 99: 72.37373737373737, 46: 69.40893719806763, 73: 73.25939019001326, 68: 76.09684361549498, 39: 64.08641975308642, 292: 91.95547945205479, 138: 73.68478260869566, 26: 55.29113601630158, 63: 79.52910052910053, 169: 93.17455621301775, 333: 105.03603603603604, 143: 82.3076923076923, 100: 79.43166666666667, 29: 53.666815942678014, 11: 43.09002861545235, 88: 74.02093301435407, 128: 73.29427083333333, 178: 74.9119850187266, 57: 81.13241436925648, 156: 97.37606837606837, 76: 87.00952813067151, 105: 84.74502164502165, 58: 76.20862068965518, 136: 75.375, 104: 76.21016483516483, 85: 68.66252100840336, 97: 79.32371134020619, 45: 64.81346153846154, 111: 84.53153153153153, 38: 68.21468144044321, 185: 84.52162162162162, 362: 67.93646408839778, 174: 101.43218390804597, 17: 47.41758682995383, 51: 62.1376858435682, 121: 105.99380165289256, 117: 93.53525641025641, 54: 69.85, 74: 72.97406866325785, 65: 70.1940170940171, 80: 83.67164634146341, 112: 88.08516483516483, 369: 90.9810298102981, 188: 96.26595744680851, 166: 87.96626506024096, 64: 81.19609375, 71: 71.77288732394366, 427: 80.43091334894613, 98: 79.70222634508349, 420: 94.3, 213: 94.11854460093896, 163: 93.4877300613497, 107: 83.84687275341481, 102: 90.34531590413944, 173: 93.39306358381504, 139: 81.76169064748201, 95: 77.54331983805668, 23: 50.715701734624915, 70: 73.13809523809523, 281: 77.79715302491103, 504: 85.43253968253968, 126: 87.87301587301587, 149: 85.1241610738255, 140: 93.74642857142857, 153: 79.52178649237473, 96: 75.64518229166667, 133: 95.18233082706767, 83: 86.41949616648412, 35: 60.71684088269454, 155: 81.51935483870967, 144: 99.8013888888889, 92: 86.64208074534162, 122: 81.81762295081967, 229: 93.7292576419214, 87: 76.35249042145594, 151: 72.03311258278146, 125: 88.24177777777778, 141: 96.60141843971631, 235: 99.10212765957446, 135: 86.92407407407407, 69: 73.65309898242369, 37: 64.36090636090636, 129: 83.13510520487264, 110: 85.44415584415584, 79: 79.24367088607595, 78: 79.1693657219973, 119: 63.448979 ...

# %%
knn_avg3=nx.k_nearest_neighbors(G)

# %%
print (knn_avg3)
# Out:
# {75: 77.99882352941177, 31: 58.04037897586284, 43: 69.43556771545828, 2: 23.927865037812683, 90: 77.11203703703704, 42: 60.331389698736636, 118: 78.43502824858757, 30: 57.107625272331155, 113: 80.56814159292036, 3: 28.27523510971787, 28: 58.709793351302785, 8: 39.26327433628319, 158: 86.37341772151899, 13: 44.994888023369036, 77: 73.6357733175915, 36: 62.516007532956685, 257: 86.91439688715953, 12: 42.094705443698736, 134: 89.48258706467662, 55: 78.45880077369439, 171: 82.84210526315789, 86: 81.7296511627907, 15: 48.993356242840775, 274: 96.15328467153284, 47: 67.27006769825918, 91: 80.11648351648351, 22: 49.707849419303166, 150: 90.85555555555555, 14: 44.20594010800196, 6: 35.63912864775997, 52: 71.10063224446786, 67: 75.60914179104478, 108: 87.86516203703704, 27: 60.657407407407405, 142: 87.4906103286385, 62: 64.69180470793374, 7: 37.66788247213779, 61: 76.44262295081967, 49: 68.4408811143505, 132: 81.35950413223141, 41: 67.15829746532759, 5: 33.02613981762918, 32: 61.44760338345865, 20: 46.04779411764706, 50: 65.12612903225806, 56: 74.32245879120879, 18: 50.58738425925926, 44: 67.23400673400674, 81: 81.11552028218695, 9: 39.82104805392477, 84: 76.93650793650794, 123: 86.35040650406503, 120: 94.29166666666667, 82: 70.11293743372217, 59: 80.08916728076639, 10: 40.97029288702929, 109: 80.96238532110091, 21: 52.61680378957866, 72: 76.99714052287581, 33: 62.90030303030303, 103: 76.49393203883496, 93: 81.32453567937439, 19: 47.950607287449394, 60: 74.33186274509804, 48: 63.18070652173913, 222: 101.52477477477477, 40: 62.843686868686866, 154: 103.51298701298701, 66: 70.86293164200141, 220: 106.10909090909091, 24: 50.449945887445885, 152: 91.66973684210527, 323: 97.31424148606811, 115: 81.92028985507247, 34: 62.29171668667467, 271: 96.6309963099631, 53: 73.98842767295598, 4: 28.074249605055293, 336: 98.73214285714286, 297: 89.98653198653199, 1: 26.308352849336455, 89: 69.29775280898876, 25: 54.5074358974359, 175: 98.65904761904761, 162: 88.1358024691358, 16: 46.23848684210526, 99: 72.37373737373737, 46: 69.40893719806763, 73: 73.25939019001326, 68: 76.09684361549498, 39: 64.08641975308642, 292: 91.95547945205479, 138: 73.68478260869566, 26: 55.29113601630158, 63: 79.52910052910053, 169: 93.17455621301775, 333: 105.03603603603604, 143: 82.3076923076923, 100: 79.43166666666667, 29: 53.666815942678014, 11: 43.09002861545235, 88: 74.02093301435407, 128: 73.29427083333333, 178: 74.9119850187266, 57: 81.13241436925648, 156: 97.37606837606837, 76: 87.00952813067151, 105: 84.74502164502165, 58: 76.20862068965518, 136: 75.375, 104: 76.21016483516483, 85: 68.66252100840336, 97: 79.32371134020619, 45: 64.81346153846154, 111: 84.53153153153153, 38: 68.21468144044321, 185: 84.52162162162162, 362: 67.93646408839778, 174: 101.43218390804597, 17: 47.41758682995383, 51: 62.1376858435682, 121: 105.99380165289256, 117: 93.53525641025641, 54: 69.85, 74: 72.97406866325785, 65: 70.1940170940171, 80: 83.67164634146341, 112: 88.08516483516483, 369: 90.9810298102981, 188: 96.26595744680851, 166: 87.96626506024096, 64: 81.19609375, 71: 71.77288732394366, 427: 80.43091334894613, 98: 79.70222634508349, 420: 94.3, 213: 94.11854460093896, 163: 93.4877300613497, 107: 83.84687275341481, 102: 90.34531590413944, 173: 93.39306358381504, 139: 81.76169064748201, 95: 77.54331983805668, 23: 50.715701734624915, 70: 73.13809523809523, 281: 77.79715302491103, 504: 85.43253968253968, 126: 87.87301587301587, 149: 85.1241610738255, 140: 93.74642857142857, 153: 79.52178649237473, 96: 75.64518229166667, 133: 95.18233082706767, 83: 86.41949616648412, 35: 60.71684088269454, 155: 81.51935483870967, 144: 99.8013888888889, 92: 86.64208074534162, 122: 81.81762295081967, 229: 93.7292576419214, 87: 76.35249042145594, 151: 72.03311258278146, 125: 88.24177777777778, 141: 96.60141843971631, 235: 99.10212765957446, 135: 86.92407407407407, 69: 73.65309898242369, 37: 64.36090636090636, 129: 83.13510520487264, 110: 85.44415584415584, 79: 79.24367088607595, 78: 79.1693657219973, 119: 63.448979 ...

# %%
r2=nx.degree_pearson_correlation_coefficient(G)
print (r2)
# Out:
# 0.205120678986

# %% [markdown]
# # Random and targeted attacks to a network

# %% [markdown]
# Resilience is the ability to provide and maintain an acceptable level of service in the face of faults and challenges to normal operation. Threats and challenges for services can range from simple misconfiguration over large scale natural disasters to targeted attacks.

# %% [markdown]
# We define a function that performs a random or targeted attack to a network according to a given strategy (random, degree based, betweenness based, etc. )

# %%
def net_attack(graph, ranked_nodes):
    
    fraction_removed=[]#here we store the tuples: (%removed nodes, size of gcc)
    
    graph1=graph.copy()
    nnodes=len(ranked_nodes)
    n=0    
    
    gcc=list(nx.connected_components(graph1))[0]
    
    gcc_size=float(len(gcc))/nnodes
    
    fraction_removed.append( (float(n)/nnodes, gcc_size) )
    
    while gcc_size>0.01:
        
        #we start from the end of the list!
        graph1.remove_node(ranked_nodes.pop())

        gcc=list(nx.connected_components(graph1))[0]
        gcc_size=float(len(gcc))/nnodes
        n+=1
        fraction_removed.append( (float(n)/nnodes, gcc_size) )
    
    return fraction_removed

# %% [markdown]
# ## Random attack

# %%
G=nx.Graph()
fh=open('./USairport_2010.txt','r')
for line in fh.readlines():
    s=line.strip().split()
    G.add_edge(int(s[0]),int(s[1]))
fh.close()

# %%
airport_nodes=G.nodes()
resilience_random=net_attack(G, airport_nodes)

# %% [markdown]
# ## Betweenness based attack

# %%
from operator import itemgetter

# %%
airport_nodes_betw=[]

betw=nx.betweenness_centrality(G)
for i in sorted(betw.items(), key=itemgetter(1)):
    airport_nodes_betw.append(i[0])


resilience_betw=net_attack(G, airport_nodes_betw)

# %% [markdown]
# ## Degree based attack

# %%
airport_nodes_degree=[]

deg=G.degree()
for i in sorted(deg.items(), key=itemgetter(1)):
    airport_nodes_degree.append(i[0])


resilience_deg=net_attack(G, airport_nodes_degree)

# %% [markdown]
# Let's compare the results.

# %%
x=[k[0] for k in resilience_random]
y=[k[1] for k in resilience_random]

x1=[k[0] for k in resilience_deg]
y1=[k[1] for k in resilience_deg]

x2=[k[0] for k in resilience_betw]
y2=[k[1] for k in resilience_betw]

plt.figure(figsize=(10,7))

plt.plot(x,y, label='random attack')
plt.plot(x1,y1, label='degree based')
plt.plot(x2,y2, label='betw based')

plt.xlabel('$f_{c}$', fontsize=18)
plt.ylabel('$LCC$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc='upper right')

# %% [markdown]
# ## Resilience of the Erdos-Renyi random network

# %%
ER=nx.fast_gnp_random_graph(2000,0.012)

# %%
ER_nodes=ER.nodes()

ER_nodes_deg=[]
for i in sorted(ER.degree().items(), key=itemgetter(1)):
    ER_nodes_deg.append(i[0])

ER_nodes_betw=[]
ER_betw=nx.betweenness_centrality(ER)
for i in sorted(ER_betw.items(), key=itemgetter(1)):
    ER_nodes_betw.append(i[0])

# %%
resilience_random=net_attack(ER, ER_nodes)
resilience_deg=net_attack(ER, ER_nodes_deg)
resilience_betw=net_attack(ER, ER_nodes_betw)

# %%
x=[k[0] for k in resilience_random]
y=[k[1] for k in resilience_random]

x1=[k[0] for k in resilience_deg]
y1=[k[1] for k in resilience_deg]

x2=[k[0] for k in resilience_betw]
y2=[k[1] for k in resilience_betw]

plt.figure(figsize=(10,7))

plt.plot(x,y, label='random attack')
plt.plot(x1,y1, label='degree based')
plt.plot(x2,y2, label='betw based')

plt.xlabel('$f_{c}$', fontsize=18)
plt.ylabel('$LCC$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc='upper right')
